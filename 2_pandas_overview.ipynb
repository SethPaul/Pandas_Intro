# %% [markdown]
# # Pandas Overview

# %% [markdown]
# Pandas is Python's version of R data frames.
#
# If you're familiar with R data frames you amy be a step ahead in some areas (and a step behind in others)

# %% [markdown]
# #### Pandas data structures:
#  - Series
#  - Dataframes

# %% [markdown]
# These data sturctures are wrappers for numpy arrays

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# Make the graphs a bit prettier, and bigger
plt.style.use('ggplot')

# This is necessary to show lots of columns in pandas 0.12.
# Not necessary in pandas 0.13.
pd.set_option('display.width', 5000)
pd.set_option('display.max_rows', 20)

plt.rcParams['figure.figsize'] = (15, 5)

# %%
broadbandDF = pd.read_csv('./datasets/broadband_speedtest.csv')

# %%
broadbandDF.head()
# Out:
#        accessingFrom  geographyId geographyName  lowerQuartileDownload  lowerQuartileUpload  medianDownload  medianUpload  numberOfTests  upperQuartileDownload  upperQuartileUpload
# 0               Home         1001       Autauga                2.23438              0.31348         4.97324       1.03272             78               13.43652              2.70508
# 1             Mobile         1001       Autauga                0.82227              0.27148         2.18652       0.78320            163                4.86426              1.40039
# 2     Small_Business         1001       Autauga                0.44336              0.59863        37.17871       4.04492              7               66.96387              4.06836
# 3           Business         1003       Baldwin                0.96777              0.81152         4.93506       4.96240              8                7.88996              8.14500
# ...

# %%
broadbandDF.tail()
# Out:
#       accessingFrom  geographyId geographyName  lowerQuartileDownload  lowerQuartileUpload  medianDownload  medianUpload  numberOfTests  upperQuartileDownload  upperQuartileUpload
# 11796          Home        72153         Yauco                0.06191              0.11500         0.43467       0.26609              8                0.97701              0.36230
# 11797        Mobile        72153         Yauco                0.38867              0.20215         0.79590       0.26319            146                1.22754              0.34570
# 11798        Mobile        78010     St. Croix                0.21191              0.16992         0.54980       0.41602            701                0.85938              0.63672
# 11799        Mobile        78020      St. John                0.16406              0.13770         0.39355       0.27441             39                0.76563              1.09668
# ...

# %%
broadbandDF.values
# Out:
# array([['Home', 1001, 'Autauga', ..., 78, 13.436520000000002,
#         2.7050799999999997],
#        ['Mobile', 1001, 'Autauga', ..., 163, 4.86426, 1.40039],
#        ['Small_Business', 1001, 'Autauga', ..., 7, 66.96387, 4.06836],
#        ...,
#        ['Mobile', 78010, 'St. Croix', ..., 701, 0.8593799999999999, 0.63672],
#        ['Mobile', 78020, 'St. John', ..., 39, 0.76563, 1.0966799999999999],
#        ['Mobile', 78030, 'St. Thomas', ..., 844, 1.6533200000000001,
#         0.41895]], dtype=object)

# %%
broadbandDF.columns
# Out:
# Index([u'accessingFrom', u'geographyId', u'geographyName', u'lowerQuartileDownload', u'lowerQuartileUpload', u'medianDownload', u'medianUpload', u'numberOfTests', u'upperQuartileDownload', u'upperQuartileUpload'], dtype='object')

# %%
broadbandDF[['accessingFrom', 'geographyId']]
# Out:
#            accessingFrom  geographyId
# 0                   Home         1001
# 1                 Mobile         1001
# 2         Small_Business         1001
# 3               Business         1003
# 4      CC_library_school         1003
# 5                   Home         1003
# 6                 Mobile         1003
# 7                  Other         1003
# 8         Small_Business         1003
# 9               Business         1005
# ...                  ...          ...
# 11791             Mobile        72147
# 11792               Home        72149
# 11793             Mobile        72149
# 11794               Home        72151
# 11795             Mobile        72151
# 11796               Home        72153
# 11797             Mobile        72153
# 11798             Mobile        78010
# 11799             Mobile        78020
# 11800             Mobile        78030
#
# [11801 rows x 2 columns]

# %%
broadbandDF.loc[:,'accessingFrom']
# Out:
# 0                     Home
# 1                   Mobile
# 2           Small_Business
# 3                 Business
# 4        CC_library_school
# 5                     Home
# 6                   Mobile
# 7                    Other
# 8           Small_Business
# 9                 Business
#                ...
# 11791               Mobile
# 11792                 Home
# 11793               Mobile
# 11794                 Home
# 11795               Mobile
# 11796                 Home
# 11797               Mobile
# 11798               Mobile
# 11799               Mobile
# 11800               Mobile
# Name: accessingFrom, dtype: object

# %%
broadbandDF.iloc[0:4, 5:8]
# Out:
#    medianDownload  medianUpload  numberOfTests
# 0         4.97324       1.03272             78
# 1         2.18652       0.78320            163
# 2        37.17871       4.04492              7
# 3         4.93506       4.96240              8

# %%
broadbandDF.ix[1:4, 'accessingFrom']
# Out:
# 1               Mobile
# 2       Small_Business
# 3             Business
# 4    CC_library_school
# Name: accessingFrom, dtype: object

# %%
broadbandDF# shift-tab
# Out:
#            accessingFrom  geographyId geographyName  lowerQuartileDownload  lowerQuartileUpload  medianDownload  medianUpload  numberOfTests  upperQuartileDownload  upperQuartileUpload
# 0                   Home         1001       Autauga                2.23438              0.31348         4.97324       1.03272             78               13.43652              2.70508
# 1                 Mobile         1001       Autauga                0.82227              0.27148         2.18652       0.78320            163                4.86426              1.40039
# 2         Small_Business         1001       Autauga                0.44336              0.59863        37.17871       4.04492              7               66.96387              4.06836
# 3               Business         1003       Baldwin                0.96777              0.81152         4.93506       4.96240              8                7.88996              8.14500
# ...

# %%
broadbandDF.columns
# Out:
# Index([u'accessingFrom', u'geographyId', u'geographyName', u'lowerQuartileDownload', u'lowerQuartileUpload', u'medianDownload', u'medianUpload', u'numberOfTests', u'upperQuartileDownload', u'upperQuartileUpload'], dtype='object')

# %%
broadbandDF.drop('geographyId', axis=1)
# Out:
#            accessingFrom geographyName  lowerQuartileDownload  lowerQuartileUpload  medianDownload  medianUpload  numberOfTests  upperQuartileDownload  upperQuartileUpload
# 0                   Home       Autauga                2.23438              0.31348         4.97324       1.03272             78               13.43652              2.70508
# 1                 Mobile       Autauga                0.82227              0.27148         2.18652       0.78320            163                4.86426              1.40039
# 2         Small_Business       Autauga                0.44336              0.59863        37.17871       4.04492              7               66.96387              4.06836
# 3               Business       Baldwin                0.96777              0.81152         4.93506       4.96240              8                7.88996              8.14500
# ...

# %%
broadbandDF.drop(2, axis=0)
# Out:
#            accessingFrom  geographyId geographyName  lowerQuartileDownload  lowerQuartileUpload  medianDownload  medianUpload  numberOfTests  upperQuartileDownload  upperQuartileUpload
# 0                   Home         1001       Autauga                2.23438              0.31348         4.97324       1.03272             78               13.43652              2.70508
# 1                 Mobile         1001       Autauga                0.82227              0.27148         2.18652       0.78320            163                4.86426              1.40039
# 3               Business         1003       Baldwin                0.96777              0.81152         4.93506       4.96240              8                7.88996              8.14500
# 4      CC_library_school         1003       Baldwin                2.20125              0.70200         2.20125       0.70200              1                2.20125              0.70200
# ...

# %%
broadbandDF.sort_values(by='medianDownload', ascending=False)
# Out:
#            accessingFrom  geographyId    geographyName  lowerQuartileDownload  lowerQuartileUpload  medianDownload  medianUpload  numberOfTests  upperQuartileDownload  upperQuartileUpload
# 11457              Other        55103         Richland              152.85645              2.06934       152.85645       2.06934              1              152.85645              2.06934
# 7440            Business        37171            Surry                3.11133              5.15039       143.82715       8.96875              2              284.54297             12.78711
# 2452      Small_Business        17063           Grundy              138.38184              1.15332       138.38184       1.15332              1              138.38184              1.15332
# 3727            Business        20151            Pratt               87.10059             10.51953        95.52783      10.83154              6               97.19727             11.20898
# ...

# %%
broadbandDF[2:5].append(broadbandDF[4:7])
# Out:
#        accessingFrom  geographyId geographyName  lowerQuartileDownload  lowerQuartileUpload  medianDownload  medianUpload  numberOfTests  upperQuartileDownload  upperQuartileUpload
# 2     Small_Business         1001       Autauga                0.44336              0.59863        37.17871       4.04492              7               66.96387              4.06836
# 3           Business         1003       Baldwin                0.96777              0.81152         4.93506       4.96240              8                7.88996              8.14500
# 4  CC_library_school         1003       Baldwin                2.20125              0.70200         2.20125       0.70200              1                2.20125              0.70200
# 4  CC_library_school         1003       Baldwin                2.20125              0.70200         2.20125       0.70200              1                2.20125              0.70200
# ...

# %%
broadbandDF.medianDownload.hist(bins=100)

# %%
broadbandDF[broadbandDF.medianDownload<20].medianDownload.hist(bins=100)

# %%
broadbandDF.boxplot(column='medianDownload', by='accessingFrom')

# %%
broadbandDF.sum()
# Out:
# accessingFrom            HomeMobileSmall_BusinessBusinessCC_library_sch...
# geographyId                                                      362164045
# geographyName            AutaugaAutaugaAutaugaBaldwinBaldwinBaldwinBald...
# lowerQuartileDownload                                              38828.5
# lowerQuartileUpload                                                16387.7
# medianDownload                                                     70039.6
# medianUpload                                                       27553.6
# numberOfTests                                                      4793552
# upperQuartileDownload                                               122767
# upperQuartileUpload                                                46990.1
# dtype: object

# %%
broadbandDF.count()
# Out:
# accessingFrom            11801
# geographyId              11801
# geographyName            11801
# lowerQuartileDownload    11801
# lowerQuartileUpload      11801
# medianDownload           11801
# medianUpload             11801
# numberOfTests            11801
# upperQuartileDownload    11801
# upperQuartileUpload      11801
# dtype: int64

# %%
broadbandDF.accessingFrom.value_counts()
# Out:
# Mobile               2986
# Home                 2965
# Small_Business       1982
# Business             1479
# CC_library_school    1327
# Other                1062
# Name: accessingFrom, dtype: int64

# %%
popped = broadbandDF.pop('accessingFrom')
popped
# Out:
# 0                     Home
# 1                   Mobile
# 2           Small_Business
# 3                 Business
# 4        CC_library_school
# 5                     Home
# 6                   Mobile
# 7                    Other
# 8           Small_Business
# 9                 Business
#                ...
# 11791               Mobile
# 11792                 Home
# 11793               Mobile
# 11794                 Home
# 11795               Mobile
# 11796                 Home
# 11797               Mobile
# 11798               Mobile
# 11799               Mobile
# 11800               Mobile
# Name: accessingFrom, dtype: object

# %%
broadbandDF.head()
# Out:
#    geographyId geographyName  lowerQuartileDownload  lowerQuartileUpload  medianDownload  medianUpload  numberOfTests  upperQuartileDownload  upperQuartileUpload
# 0         1001       Autauga                2.23438              0.31348         4.97324       1.03272             78               13.43652              2.70508
# 1         1001       Autauga                0.82227              0.27148         2.18652       0.78320            163                4.86426              1.40039
# 2         1001       Autauga                0.44336              0.59863        37.17871       4.04492              7               66.96387              4.06836
# 3         1003       Baldwin                0.96777              0.81152         4.93506       4.96240              8                7.88996              8.14500
# 4         1003       Baldwin                2.20125              0.70200         2.20125       0.70200              1                2.20125              0.70200

# %%
broadbandDF['accessingFrom']=popped

# %%
broadbandDF.head()
# Out:
#    geographyId geographyName  lowerQuartileDownload  lowerQuartileUpload  medianDownload  medianUpload  numberOfTests  upperQuartileDownload  upperQuartileUpload      accessingFrom
# 0         1001       Autauga                2.23438              0.31348         4.97324       1.03272             78               13.43652              2.70508               Home
# 1         1001       Autauga                0.82227              0.27148         2.18652       0.78320            163                4.86426              1.40039             Mobile
# 2         1001       Autauga                0.44336              0.59863        37.17871       4.04492              7               66.96387              4.06836     Small_Business
# 3         1003       Baldwin                0.96777              0.81152         4.93506       4.96240              8                7.88996              8.14500           Business
# ...

# %%
broadbandDF.medianDownload.max()
# Out:
# 152.85645

# %%
broadbandDF.medianDownload.idxmax()
# Out:
# 11457

# %%
groupedBBDF = broadbandDF.groupby('accessingFrom')
groupedBBDF

# %%
groupedBBDF.groups.keys()
# Out:
# ['CC_library_school', 'Business', 'Mobile', 'Other', 'Small_Business', 'Home']

# %%
groupedBBDF.mean()
# Out:
#                     geographyId  lowerQuartileDownload  lowerQuartileUpload  medianDownload  medianUpload  numberOfTests  upperQuartileDownload  upperQuartileUpload
# accessingFrom
# Business           30191.875592               6.233899             3.012912       10.546265      5.069238      17.679513              17.209628             8.436190
# CC_library_school  29627.567445               7.232249             4.009948       11.990092      6.411448      12.934439              19.678513            10.325785
# Home               31234.486341               1.913851             0.474441        4.425630      0.875037     253.767285               8.752926             1.518436
# Mobile             31377.635968               0.769426             0.380100        2.004580      0.802271    1322.401206               4.682919             1.705518
# ...

# %%
downers = broadbandDF.loc[1:20,broadbandDF[1:20].columns.str.contains('Download')]
downers.head()
# Out:
#    lowerQuartileDownload  medianDownload  upperQuartileDownload
# 1                0.82227         2.18652                4.86426
# 2                0.44336        37.17871               66.96387
# 3                0.96777         4.93506                7.88996
# 4                2.20125         2.20125                2.20125
# 5                1.24220         2.76063                5.61737

# %%
broadbandDF.columns.str.contains('Download')
# Out:
# array([False, False,  True, False,  True, False, False,  True, False, False], dtype=bool)

# %%
downers['geographyId']=broadbandDF.geographyId
downers.head()
# Out:
#    lowerQuartileDownload  medianDownload  upperQuartileDownload  geographyId
# 1                0.82227         2.18652                4.86426         1001
# 2                0.44336        37.17871               66.96387         1001
# 3                0.96777         4.93506                7.88996         1003
# 4                2.20125         2.20125                2.20125         1003
# 5                1.24220         2.76063                5.61737         1003

# %%
downers = broadbandDF.loc[1:10,broadbandDF.columns.str.contains('Download')].copy()
downers['geographyId']=broadbandDF.loc[1:10,'geographyId']
downers['accessingFrom']=broadbandDF.loc[1:10,'accessingFrom']
downers.head()
# Out:
#    lowerQuartileDownload  medianDownload  upperQuartileDownload  geographyId      accessingFrom
# 1                0.82227         2.18652                4.86426         1001             Mobile
# 2                0.44336        37.17871               66.96387         1001     Small_Business
# 3                0.96777         4.93506                7.88996         1003           Business
# 4                2.20125         2.20125                2.20125         1003  CC_library_school
# 5                1.24220         2.76063                5.61737         1003               Home

# %%
uppers = broadbandDF.loc[1:10,broadbandDF.columns.str.contains('Upload')].copy()
uppers['geographyId']=broadbandDF.loc[1:10,'geographyId']
uppers['accessingFrom']=broadbandDF.loc[1:10,'accessingFrom']
uppers.head()
# Out:
#    lowerQuartileUpload  medianUpload  upperQuartileUpload  geographyId      accessingFrom
# 1              0.27148       0.78320              1.40039         1001             Mobile
# 2              0.59863       4.04492              4.06836         1001     Small_Business
# 3              0.81152       4.96240              8.14500         1003           Business
# 4              0.70200       0.70200              0.70200         1003  CC_library_school
# 5              0.34300       0.64941              0.91309         1003               Home

# %%
pd.concat([uppers, downers])
# Out:
#         accessingFrom  geographyId  lowerQuartileDownload  lowerQuartileUpload  medianDownload  medianUpload  upperQuartileDownload  upperQuartileUpload
# 1              Mobile         1001                    NaN              0.27148             NaN       0.78320                    NaN              1.40039
# 2      Small_Business         1001                    NaN              0.59863             NaN       4.04492                    NaN              4.06836
# 3            Business         1003                    NaN              0.81152             NaN       4.96240                    NaN              8.14500
# 4   CC_library_school         1003                    NaN              0.70200             NaN       0.70200                    NaN              0.70200
# 5                Home         1003                    NaN              0.34300             NaN       0.64941                    NaN              0.91309
# ...

# %%
pd.merge(uppers, downers)
# Out:
#    lowerQuartileUpload  medianUpload  upperQuartileUpload  geographyId      accessingFrom  lowerQuartileDownload  medianDownload  upperQuartileDownload
# 0              0.27148       0.78320              1.40039         1001             Mobile                0.82227         2.18652                4.86426
# 1              0.59863       4.04492              4.06836         1001     Small_Business                0.44336        37.17871               66.96387
# 2              0.81152       4.96240              8.14500         1003           Business                0.96777         4.93506                7.88996
# 3              0.70200       0.70200              0.70200         1003  CC_library_school                2.20125         2.20125                2.20125
# 4              0.34300       0.64941              0.91309         1003               Home                1.24220         2.76063                5.61737
# ...

# %%
pd.merge(uppers, downers[20:0:-1])
# Out:
#    lowerQuartileUpload  medianUpload  upperQuartileUpload  geographyId      accessingFrom  lowerQuartileDownload  medianDownload  upperQuartileDownload
# 0              0.59863       4.04492              4.06836         1001     Small_Business                0.44336        37.17871               66.96387
# 1              0.81152       4.96240              8.14500         1003           Business                0.96777         4.93506                7.88996
# 2              0.70200       0.70200              0.70200         1003  CC_library_school                2.20125         2.20125                2.20125
# 3              0.34300       0.64941              0.91309         1003               Home                1.24220         2.76063                5.61737
# 4              0.30957       0.63086              1.04785         1003             Mobile                0.56543         1.45654                3.37793
# ...

# %%
downers2=downers.sample(frac=0.3)
downers2.shape
# Out:
# (3, 5)

# %%
downers2
# Out:
#    lowerQuartileDownload  medianDownload  upperQuartileDownload  geographyId accessingFrom
# 3                0.96777         4.93506                7.88996         1003      Business
# 6                0.56543         1.45654                3.37793         1003        Mobile
# 7                1.59414         1.59414                6.06348         1003         Other

# %%
pd.merge(downers2, uppers)
# Out:
#    lowerQuartileDownload  medianDownload  upperQuartileDownload  geographyId accessingFrom  lowerQuartileUpload  medianUpload  upperQuartileUpload
# 0                0.96777         4.93506                7.88996         1003      Business              0.81152       4.96240              8.14500
# 1                0.56543         1.45654                3.37793         1003        Mobile              0.30957       0.63086              1.04785
# 2                1.59414         1.59414                6.06348         1003         Other              0.28500       0.40820              1.06200

# %%
pd.merge(downers2, uppers, how='outer')
# Out:
#    lowerQuartileDownload  medianDownload  upperQuartileDownload  geographyId      accessingFrom  lowerQuartileUpload  medianUpload  upperQuartileUpload
# 0                0.96777         4.93506                7.88996       1003.0           Business              0.81152       4.96240              8.14500
# 1                0.56543         1.45654                3.37793       1003.0             Mobile              0.30957       0.63086              1.04785
# 2                1.59414         1.59414                6.06348       1003.0              Other              0.28500       0.40820              1.06200
# 3                    NaN             NaN                    NaN       1001.0             Mobile              0.27148       0.78320              1.40039
# 4                    NaN             NaN                    NaN       1001.0     Small_Business              0.59863       4.04492              4.06836
# ...

# %%
pd.merge(downers2, uppers, how='left')
# Out:
#    lowerQuartileDownload  medianDownload  upperQuartileDownload  geographyId accessingFrom  lowerQuartileUpload  medianUpload  upperQuartileUpload
# 0                0.96777         4.93506                7.88996         1003      Business              0.81152       4.96240              8.14500
# 1                0.56543         1.45654                3.37793         1003        Mobile              0.30957       0.63086              1.04785
# 2                1.59414         1.59414                6.06348         1003         Other              0.28500       0.40820              1.06200

# %%
pd.merge(downers2, uppers, how='right')
# Out:
#    lowerQuartileDownload  medianDownload  upperQuartileDownload  geographyId      accessingFrom  lowerQuartileUpload  medianUpload  upperQuartileUpload
# 0                0.96777         4.93506                7.88996       1003.0           Business              0.81152       4.96240              8.14500
# 1                0.56543         1.45654                3.37793       1003.0             Mobile              0.30957       0.63086              1.04785
# 2                1.59414         1.59414                6.06348       1003.0              Other              0.28500       0.40820              1.06200
# 3                    NaN             NaN                    NaN       1001.0             Mobile              0.27148       0.78320              1.40039
# 4                    NaN             NaN                    NaN       1001.0     Small_Business              0.59863       4.04492              4.06836
# ...

# %%
# !head ./datasets/national_county.txt
# Out:
# AL,01,001,Autauga County,H1
# AL,01,003,Baldwin County,H1
# AL,01,005,Barbour County,H1
# AL,01,007,Bibb County,H1
# AL,01,009,Blount County,H1
# AL,01,011,Bullock County,H1
# AL,01,013,Butler County,H1
# AL,01,015,Calhoun County,H1
# AL,01,017,Chambers County,H1
# AL,01,019,Cherokee County,H1

# %%
fipsDF = pd.read_csv('./datasets/national_county.txt', header=None)
fipsDF
# Out:
#        0   1    2                    3   4
# 0     AL   1    1       Autauga County  H1
# 1     AL   1    3       Baldwin County  H1
# 2     AL   1    5       Barbour County  H1
# 3     AL   1    7          Bibb County  H1
# 4     AL   1    9        Blount County  H1
# 5     AL   1   11       Bullock County  H1
# 6     AL   1   13        Butler County  H1
# 7     AL   1   15       Calhoun County  H1
# 8     AL   1   17      Chambers County  H1
# 9     AL   1   19      Cherokee County  H1
# ...   ..  ..  ...                  ...  ..
# 3225  PR  72  143  Vega Alta Municipio  H1
# 3226  PR  72  145  Vega Baja Municipio  H1
# 3227  PR  72  147    Vieques Municipio  H1
# 3228  PR  72  149   Villalba Municipio  H1
# 3229  PR  72  151    Yabucoa Municipio  H1
# 3230  PR  72  153      Yauco Municipio  H1
# 3231  UM  74  300       Midway Islands  H4
# 3232  VI  78   10     St. Croix Island  H4
# 3233  VI  78   20      St. John Island  H4
# 3234  VI  78   30    St. Thomas Island  H4
#
# ...

# %%
fipsDF.columns = ['state', 'part1', 'part2', 'county', 'FIPS class code']

# %%
fipsDF['fips'] = fipsDF.part1.astype(str) + fipsDF.part2.astype(str).apply(lambda x: x.zfill(3))
fipsDF.fips.head()
# Out:
# 0    1001
# 1    1003
# 2    1005
# 3    1007
# 4    1009
# Name: fips, dtype: object

# %%
fipsDF = pd.read_csv('./datasets/national_county.txt', header=None, \
                     names= ['state', 'part1', 'part2', 'county', 'FIPS class code'],\
                    dtype={'state': str, 'part1': str, 'part2': str, 'county': str,\
                           'FIPS class code': str})
fipsDF
# Out:
#      state part1 part2               county FIPS class code
# 0       AL    01   001       Autauga County              H1
# 1       AL    01   003       Baldwin County              H1
# 2       AL    01   005       Barbour County              H1
# 3       AL    01   007          Bibb County              H1
# 4       AL    01   009        Blount County              H1
# 5       AL    01   011       Bullock County              H1
# 6       AL    01   013        Butler County              H1
# 7       AL    01   015       Calhoun County              H1
# 8       AL    01   017      Chambers County              H1
# 9       AL    01   019      Cherokee County              H1
# ...    ...   ...   ...                  ...             ...
# 3225    PR    72   143  Vega Alta Municipio              H1
# 3226    PR    72   145  Vega Baja Municipio              H1
# 3227    PR    72   147    Vieques Municipio              H1
# 3228    PR    72   149   Villalba Municipio              H1
# ...

# %%
fipsDF['fips'] = fipsDF.part1 + fipsDF.part2
fipsDF['fips']
# Out:
# 0       01001
# 1       01003
# 2       01005
# 3       01007
# 4       01009
# 5       01011
# 6       01013
# 7       01015
# 8       01017
# 9       01019
#         ...
# 3225    72143
# 3226    72145
# 3227    72147
# 3228    72149
# 3229    72151
# 3230    72153
# 3231    74300
# 3232    78010
# 3233    78020
# 3234    78030
# Name: fips, dtype: object

# %%
pd.merge(broadbandDF, fipsDF, how='left', left_on= 'geographyId', right_on= 'fips')
# Out:
#        geographyId geographyName  lowerQuartileDownload  lowerQuartileUpload  medianDownload  medianUpload  numberOfTests  upperQuartileDownload  upperQuartileUpload      accessingFrom state part1 part2 county FIPS class code fips
# 0             1001       Autauga                2.23438              0.31348         4.97324       1.03272             78               13.43652              2.70508               Home   NaN   NaN   NaN    NaN             NaN  NaN
# 1             1001       Autauga                0.82227              0.27148         2.18652       0.78320            163                4.86426              1.40039             Mobile   NaN   NaN   NaN    NaN             NaN  NaN
# 2             1001       Autauga                0.44336              0.59863        37.17871       4.04492              7               66.96387              4.06836     Small_Business   NaN   NaN   NaN    NaN             NaN  NaN
# ...

# %%
broadbandDF.geographyId = broadbandDF.geographyId.astype(str).apply(lambda x: x.zfill(5))
broadbandDF.head()
# Out:
#   geographyId geographyName  lowerQuartileDownload  lowerQuartileUpload  medianDownload  medianUpload  numberOfTests  upperQuartileDownload  upperQuartileUpload      accessingFrom
# 0       01001       Autauga                2.23438              0.31348         4.97324       1.03272             78               13.43652              2.70508               Home
# 1       01001       Autauga                0.82227              0.27148         2.18652       0.78320            163                4.86426              1.40039             Mobile
# 2       01001       Autauga                0.44336              0.59863        37.17871       4.04492              7               66.96387              4.06836     Small_Business
# 3       01003       Baldwin                0.96777              0.81152         4.93506       4.96240              8                7.88996              8.14500           Business
# ...

# %%
broadband_with_stateDF = pd.merge(broadbandDF, fipsDF, \
                                  how='left', left_on= 'geographyId', \
                                  right_on= 'fips')
broadband_with_stateDF
# Out:
#       geographyId geographyName  lowerQuartileDownload  lowerQuartileUpload  medianDownload  medianUpload  numberOfTests  upperQuartileDownload  upperQuartileUpload      accessingFrom state part1 part2              county FIPS class code   fips
# 0           01001       Autauga                2.23438              0.31348         4.97324       1.03272             78               13.43652              2.70508               Home    AL    01   001      Autauga County              H1  01001
# 1           01001       Autauga                0.82227              0.27148         2.18652       0.78320            163                4.86426              1.40039             Mobile    AL    01   001      Autauga County              H1  01001
# 2           01001       Autauga                0.44336              0.59863        37.17871       4.04492              7               66.96387              4.06836     Small_Business    AL    01   001      Autauga County              H1  01001
# ...

# %%
broadband_with_stateDF.set_index('state')
# Out:
#       geographyId geographyName  lowerQuartileDownload  lowerQuartileUpload  medianDownload  medianUpload  numberOfTests  upperQuartileDownload  upperQuartileUpload      accessingFrom part1 part2              county FIPS class code   fips
# state
# AL          01001       Autauga                2.23438              0.31348         4.97324       1.03272             78               13.43652              2.70508               Home    01   001      Autauga County              H1  01001
# AL          01001       Autauga                0.82227              0.27148         2.18652       0.78320            163                4.86426              1.40039             Mobile    01   001      Autauga County              H1  01001
# AL          01001       Autauga                0.44336              0.59863        37.17871       4.04492              7               66.96387              4.06836     Small_Business    01   001      Autauga County              H1  01001
# ...

# %%
broadband_with_stateDF.set_index(['accessingFrom', 'geographyId']).unstack('accessingFrom')
# Out:
#               geographyName                                                                    lowerQuartileDownload                                           ...       FIPS class code                                 fips
# accessingFrom      Business CC_library_school       Home      Mobile      Other Small_Business              Business CC_library_school      Home   Mobile      ...                  Home Mobile Other Small_Business Business CC_library_school   Home Mobile  Other Small_Business
# geographyId                                                                                                                                                    ...
# 01001                  None              None    Autauga     Autauga       None        Autauga                   NaN               NaN   2.23438  0.82227      ...                    H1     H1  None             H1     None              None  01001  01001   None          01001
# ...
